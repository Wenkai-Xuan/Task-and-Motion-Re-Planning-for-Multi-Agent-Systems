# %%
import pandas as pd
import json
import numpy as np
import os

# %%
df = pd.read_parquet('samples_000080000_to_000080868.parquet') # one train dataset of random scene

# %%
df['obj_file'][0]['objects']
# Out:
# array([{'goal_pos': array([ 0.44310605, -0.70788585,  0.185     ]), 'goal_quat': array([0.19505683, 0.        , 0.        , 0.98079194]), 'shape': array([0.19, 0.05, 0.27]), 'start_pos': array([0.65363407, 1.29098271, 0.185     ]), 'start_quat': array([0.84497859, 0.        , 0.        , 0.53480013])},
#        {'goal_pos': array([0.24967307, 0.3582663 , 0.135     ]), 'goal_quat': array([0.71230719, 0.        , 0.        , 0.70186784]), 'shape': array([0.23, 0.22, 0.17]), 'start_pos': array([ 0.69461814, -0.58824875,  0.135     ]), 'start_quat': array([ 0.88349256, -0.        , -0.        , -0.46844519])},
#        {'goal_pos': array([-1.45286802, -0.43114846,  0.095     ]), 'goal_quat': array([0.7556173 , 0.        , 0.        , 0.65501335]), 'shape': array([0.19, 0.22, 0.09]), 'start_pos': array([-0.46952242,  0.08354221,  0.095     ]), 'start_quat': array([ 0.48991374, -0.        , -0.        , -0.87177091])}],
#       dtype=object)

# %%
df['robot_file'][0]['robots']
# Out:
# array([{'base_pos': array([0.78679577, 0.60309857, 0.        ]), 'base_quat': array([6.123234e-17, 0.000000e+00, 0.000000e+00, 1.000000e+00]), 'home_pose': array([ 0.  ,  0.5 , -1.2 ,  0.  ,  1.57,  1.57]), 'start_pose': array([ 0.  ,  0.5 , -1.2 ,  0.  ,  1.57,  1.57]), 'type': 'ur5_vacuum'},
#        {'base_pos': array([ 0.07111342, -0.3053829 ,  0.        ]), 'base_quat': array([6.123234e-17, 0.000000e+00, 0.000000e+00, 1.000000e+00]), 'home_pose': array([ 0.  ,  0.5 , -1.2 ,  0.  ,  1.57,  1.57]), 'start_pose': array([ 0.  ,  0.5 , -1.2 ,  0.  ,  1.57,  1.57]), 'type': 'ur5_vacuum'},
#        {'base_pos': array([-0.85790919, -0.29771567,  0.        ]), 'base_quat': array([1., 0., 0., 0.]), 'home_pose': array([ 0.  ,  0.5 , -1.2 ,  0.  ,  1.57,  1.57]), 'start_pose': array([ 0.  ,  0.5 , -1.2 ,  0.  ,  1.57,  1.57]), 'type': 'ur5_vacuum'}],
#       dtype=object)

# %%
dir(df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
# ...

# %%
df.keys
# Out:
# <bound method NDFrame.keys of                                               obj_file  \
# 0    {'objects': [{'goal_pos': [ 0.44310605 -0.7078...
# 1    {'objects': [{'goal_pos': [ 0.44310605 -0.7078...
# 2    {'objects': [{'goal_pos': [ 0.44310605 -0.7078...
# 3    {'objects': [{'goal_pos': [ 0.44310605 -0.7078...
# 4    {'objects': [{'goal_pos': [ 0.44310605 -0.7078...
# ..                                                 ...
# 864  {'objects': [{'goal_pos': [0.26255497 0.115550...
# 865  {'objects': [{'goal_pos': [0.26255497 0.115550...
# 866  {'objects': [{'goal_pos': [0.26255497 0.115550...
# 867  {'objects': [{'goal_pos': [0.26255497 0.115550...
# 868  {'objects': [{'goal_pos': [0.26255497 0.115550...
#
#                                             robot_file  \
# 0    {'robots': [{'base_pos': [0.78679577 0.6030985...
# 1    {'robots': [{'base_pos': [0.78679577 0.6030985...
# 2    {'robots': [{'base_pos': [0.78679577 0.6030985...
# ...

# %%
df['metadata'][0]
# Out:
# {'metadata': {'cumulative_compute_time': 112711,
#   'folder': 'out/run_id_202405270718/success/envId_5/random_search_20240527_062331/103/',
#   'makespan': 388.0,
#   'num_objects': 3,
#   'num_robots': 3}}

# %%
df['plan'][0]
# Out:
# array([{'robot': 'a2_', 'tasks': array([{'algorithm': 'rrt', 'end': 244.0, 'name': 'pick', 'object_index': 2, 'start': 228.0},
#               {'algorithm': 'rrt', 'end': 306.0, 'name': 'place', 'object_index': 2, 'start': 244.0},
#               {'algorithm': 'rrt', 'end': 354.0, 'name': 'exit', 'object_index': 2, 'start': 306.0}],
#              dtype=object)}                                                                                                   ,
#        {'robot': 'a0_', 'tasks': array([{'algorithm': 'rrt', 'end': 66.0, 'name': 'pick', 'object_index': 0, 'start': 37.0},
#               {'algorithm': '', 'end': 115.0, 'name': 'handover', 'object_index': 0, 'start': 66.0},
#               {'algorithm': 'rrt', 'end': 135.0, 'name': 'exit', 'object_index': 0, 'start': 115.0}],
#              dtype=object)}                                                                                                 ,
# ...

# %%
df['sequence'][0]
# Out:
# {'tasks': array([{'object': 2, 'primitive': 'pickpick1', 'robots': array(['a1_', 'a2_'], dtype=object)},
#         {'object': 0, 'primitive': 'handover', 'robots': array(['a0_', 'a1_'], dtype=object)},
#         {'object': 1, 'primitive': 'pick', 'robots': array(['a1_'], dtype=object)},
#         {'object': 2, 'primitive': 'pickpick2', 'robots': array(['a1_', 'a2_'], dtype=object)}],
#        dtype=object)}

# %%
df['scene'][0]
# Out:
# {'Objects': {'obj1': {'goal': {'abs_pos': array([ 0.44310605, -0.65788585,  0.735     ]),
#     'abs_quat': array([0.19505683, 0.        , 0.        , 0.98079194]),
#     'parent': 'table',
#     'pos': array([ 0.44310605, -0.70788585,  0.185     ]),
#     'quat': array([0.19505683, 0.        , 0.        , 0.98079194])},
#    'size': array([0.19, 0.05, 0.27, 0.01]),
#    'start': {'abs_pos': array([0.65363407, 1.34098271, 0.735     ]),
#     'abs_quat': array([0.84497859, 0.        , 0.        , 0.53480013]),
#     'parent': 'table',
#     'pos': array([0.65363407, 1.29098271, 0.185     ]),
#     'quat': array([0.84497859, 0.        , 0.        , 0.53480013])}},
#   'obj2': {'goal': {'abs_pos': array([0.24967307, 0.4082663 , 0.685     ]),
#     'abs_quat': array([0.71230719, 0.        , 0.        , 0.70186784]),
#     'parent': 'table',
#     'pos': array([0.24967307, 0.3582663 , 0.135     ]),
#     'quat': array([0.71230719, 0.        , 0.        , 0.70186784])},
# ...

# %%
df['trajectory'][0]['robots']
# Out:
# array([{'ee_type': 'vacuum', 'name': 'a2_', 'steps': array([{'action': 'none', 'ee_pos': array([-0.60610852, -0.38116004,  1.34490183]), 'ee_quat': array([5.28949518e-04, 9.06702103e-01, 1.93081647e-04, 4.21771240e-01]), 'joint_state': array([ 0.  ,  0.5 , -1.2 ,  0.  ,  1.57,  1.57])},
#               {'action': 'none', 'ee_pos': array([-0.60610852, -0.38116004,  1.34490183]), 'ee_quat': array([5.28949518e-04, 9.06702103e-01, 1.93081647e-04, 4.21771240e-01]), 'joint_state': array([ 0.  ,  0.5 , -1.2 ,  0.  ,  1.57,  1.57])},
#               {'action': 'none', 'ee_pos': array([-0.60610852, -0.38116004,  1.34490183]), 'ee_quat': array([5.28949518e-04, 9.06702103e-01, 1.93081647e-04, 4.21771240e-01]), 'joint_state': array([ 0.  ,  0.5 , -1.2 ,  0.  ,  1.57,  1.57])},
# ...

# %%
df['trajectory'][0]['objs']
# Out:
# array([{'name': 'obj1', 'steps': array([{'pos': array([0.65363407, 1.34098271, 0.735     ]), 'quat': array([0.84497859, 0.        , 0.        , 0.53480013])},
#               {'pos': array([0.65363407, 1.34098271, 0.735     ]), 'quat': array([0.84497859, 0.        , 0.        , 0.53480013])},
#               {'pos': array([0.65363407, 1.34098271, 0.735     ]), 'quat': array([0.84497859, 0.        , 0.        , 0.53480013])},
#               {'pos': array([0.65363407, 1.34098271, 0.735     ]), 'quat': array([0.84497859, 0.        , 0.        , 0.53480013])},
#               {'pos': array([0.65363407, 1.34098271, 0.735     ]), 'quat': array([0.84497859, 0.        , 0.        , 0.53480013])},
#               {'pos': array([0.65363407, 1.34098271, 0.735     ]), 'quat': array([0.84497859, 0.        , 0.        , 0.53480013])},
#               {'pos': array([0.65363407, 1.34098271, 0.735     ]), 'quat': array([0.84497859, 0.        , 0.        , 0.53480013])},
# ...
