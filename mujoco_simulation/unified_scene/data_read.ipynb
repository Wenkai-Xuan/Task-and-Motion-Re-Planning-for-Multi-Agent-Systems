# %%
import pandas as pd
import json
import numpy as np
import os

# %%
df = pd.read_parquet('samples_000080000_to_000080868.parquet')

# %%
df['obj_file'][861]['objects']
# Out:
# array([{'goal_pos': array([-0.85623083, -0.73455477,  0.075     ]), 'goal_quat': array([0.98964829, 0.        , 0.        , 0.14351399]), 'shape': array([0.08, 0.14, 0.05]), 'start_pos': array([0.03020026, 0.75512072, 0.075     ]), 'start_quat': array([0.7133066 , 0.        , 0.        , 0.70085213])},
#        {'goal_pos': array([-0.98534163,  0.55242765,  0.11      ]), 'goal_quat': array([ 0.74759703, -0.        , -0.        , -0.6641526 ]), 'shape': array([0.05, 0.11, 0.12]), 'start_pos': array([0.10546141, 0.24341595, 0.11      ]), 'start_quat': array([ 0.19729825, -0.        , -0.        , -0.98034351])}],
#       dtype=object)

# %%
df['trajectory'][861]['objs'][0]['steps']
# Out:
# array([{'pos': array([0.03020026, 0.80512072, 0.625     ]), 'quat': array([0.7133066 , 0.        , 0.        , 0.70085213])},
#        {'pos': array([0.03020026, 0.80512072, 0.625     ]), 'quat': array([0.7133066 , 0.        , 0.        , 0.70085213])},
#        {'pos': array([0.03020026, 0.80512072, 0.625     ]), 'quat': array([0.7133066 , 0.        , 0.        , 0.70085213])},
#        {'pos': array([0.03020026, 0.80512072, 0.625     ]), 'quat': array([0.7133066 , 0.        , 0.        , 0.70085213])},
#        {'pos': array([0.03020026, 0.80512072, 0.625     ]), 'quat': array([0.7133066 , 0.        , 0.        , 0.70085213])},
#        {'pos': array([0.03020026, 0.80512072, 0.625     ]), 'quat': array([0.7133066 , 0.        , 0.        , 0.70085213])},
#        {'pos': array([0.03020026, 0.80512072, 0.625     ]), 'quat': array([0.7133066 , 0.        , 0.        , 0.70085213])},
# ...

# %%
df['scene'][5]
# Out:
# {'Objects': {'obj1': {'goal': {'abs_pos': array([0.99165794, 0.93015619, 0.685     ]),
#     'abs_quat': array([ 0.87857692, -0.        , -0.        , -0.47760088]),
#     'parent': 'table',
#     'pos': array([0.99165794, 0.88015619, 0.135     ]),
#     'quat': array([ 0.87857692, -0.        , -0.        , -0.47760088])},
#    'size': array([0.18, 0.2 , 0.17, 0.01]),
#    'start': {'abs_pos': array([-0.01340796,  0.6239036 ,  0.685     ]),
#     'abs_quat': array([0.77371179, 0.        , 0.        , 0.63353774]),
#     'parent': 'table',
#     'pos': array([-0.01340796,  0.5739036 ,  0.135     ]),
#     'quat': array([0.77371179, 0.        , 0.        , 0.63353774])}},
#   'obj2': {'goal': {'abs_pos': array([-0.97108162, -0.02812088,  0.645     ]),
#     'abs_quat': array([0.52469642, 0.        , 0.        , 0.85128941]),
#     'parent': 'table',
#     'pos': array([-0.97108162, -0.07812088,  0.095     ]),
#     'quat': array([0.52469642, 0.        , 0.        , 0.85128941])},
# ...

# %%
for sample_indx in range(868):
    obj_num = df['obj_file'][sample_indx]['objects'].size
    robot_num = df['robot_file'][sample_indx]['robots'].size
    if (obj_num == 3 and robot_num == 4):
        print(sample_indx)
# Out:
# 496
# 497
# 498
# 499
# 500
# 501
# 502
# 503
# 504
# 505
# 506
# 507
# 508
# 509
# 510
# 511
# 512
# 513
# 514
# 515
# 516
# 517
# 518
# 519
# 520
# 521
# 522
# 523
# 524
# 525
# 526
# 527
# 528
# 529
# 530
# 531
# 532
# 533
# 534
# 535
# 536
# 537
# 538
# 539
# 540
# 541
# 542
# 543
# 544
# 545
# 546
# 547
# 548
# 549
# 550
# 551
# 552
# 553
# 554
# 555
# 556
# 557
# 558
# 559
# 560
# 561
# 562
# 563
# 564
# 565
# 566
# 567
# 568
# 569
# 570
# 571
# 572
# 573
# 574
# 575
# 576
# 577
# 578
# 579
# 580
# 706
# 707
# 708
# 709
# 710
# 711
# 712
# 713
# 714
# 715
# 716
# 717
# 718
# 719
# 720
# 721
# 722
# 723
# 724
# 725
# 726
# 727
# 728
# 729
# 730
# 731
# 732
# 733
# 734
# 735
# 736
# 737
# 738
# 739
# 740
# 741
# 742
# 743
# 744
# 745
# 746
# 747
# 748
# 749
# 750
# 751
# 752
# 753
# 754
# 755
# 756
# 757
# 758
# 759
# 760
# 761
# 762
# 763
# 764
# 765
# 766
# 767
# 768
# 769
# 770
# 771
# 772
# 773
# 774
# 775
# 776
# 777
# 778
# 779
# 780
# 781
# 782
# 783
# 784
# 785
# 786
# ...

# %%
df['scene'][520]
# Out:
# {'Objects': {'obj1': {'goal': {'abs_pos': array([-0.0793171 ,  0.67006369,  0.68      ]),
#     'abs_quat': array([0.57328949, 0.        , 0.        , 0.81935289]),
#     'parent': 'table',
#     'pos': array([-0.0793171 ,  0.62006369,  0.13      ]),
#     'quat': array([0.57328949, 0.        , 0.        , 0.81935289])},
#    'size': array([0.07, 0.31, 0.16, 0.01]),
#    'start': {'abs_pos': array([-0.54004653, -0.82543559,  0.68      ]),
#     'abs_quat': array([0.77579737, 0.        , 0.        , 0.63098212]),
#     'parent': 'table',
#     'pos': array([-0.54004653, -0.87543559,  0.13      ]),
#     'quat': array([0.77579737, 0.        , 0.        , 0.63098212])}},
#   'obj2': {'goal': {'abs_pos': array([0.61833301, 0.99562547, 0.635     ]),
#     'abs_quat': array([ 0.83039172, -0.        , -0.        , -0.55718004]),
#     'parent': 'table',
#     'pos': array([0.61833301, 0.94562547, 0.085     ]),
#     'quat': array([ 0.83039172, -0.        , -0.        , -0.55718004])},
# ...

# %%
ini_obj = df['obj_file'][520]['objects'].tolist()
ini_rob = df['robot_file'][520]['robots'].tolist()

# %%
ini_obj[0]
# Out:
# {'goal_pos': array([-0.0793171 ,  0.62006369,  0.13      ]),
#  'goal_quat': array([0.57328949, 0.        , 0.        , 0.81935289]),
#  'shape': array([0.07, 0.31, 0.16]),
#  'start_pos': array([-0.54004653, -0.87543559,  0.13      ]),
#  'start_quat': array([0.77579737, 0.        , 0.        , 0.63098212])}

# %%
ini_rob[0]
# Out:
# {'base_pos': array([ 0.65984349, -0.91635504,  0.        ]),
#  'base_quat': array([6.123234e-17, 0.000000e+00, 0.000000e+00, 1.000000e+00]),
#  'home_pose': array([ 0.  ,  0.5 , -1.2 ,  0.  ,  1.57,  1.57]),
#  'start_pose': array([ 0.  ,  0.5 , -1.2 ,  0.  ,  1.57,  1.57]),
#  'type': 'ur5_vacuum'}

# %%
df['scene'][5]['Robots']
# Out:
# {'a0_': {'base_pose': {'pos': array([0.78679577, 0.60309857, 0.        ]),
#    'quat': array([6.123234e-17, 0.000000e+00, 0.000000e+00, 1.000000e+00])},
#   'end_effector_type': 1,
#   'home_pose': array([ 0.  ,  0.5 , -1.2 ,  0.  ,  1.57,  1.57]),
#   'initial_pose': array([ 0.  ,  0.5 , -1.2 ,  0.  ,  1.57,  1.57]),
#   'parent': 'table',
#   'type': 0},
#  'a1_': {'base_pose': {'pos': array([ 0.07111342, -0.3053829 ,  0.        ]),
#    'quat': array([6.123234e-17, 0.000000e+00, 0.000000e+00, 1.000000e+00])},
#   'end_effector_type': 1,
#   'home_pose': array([ 0.  ,  0.5 , -1.2 ,  0.  ,  1.57,  1.57]),
#   'initial_pose': array([ 0.  ,  0.5 , -1.2 ,  0.  ,  1.57,  1.57]),
#   'parent': 'table',
#   'type': 0},
#  'a2_': {'base_pose': {'pos': array([-0.85790919, -0.29771567,  0.        ]),
#    'quat': array([1., 0., 0., 0.])},
#   'end_effector_type': 1.0,
#   'home_pose': array([ 0.  ,  0.5 , -1.2 ,  0.  ,  1.57,  1.57]),
# ...

# %%
with open('random_scene_520.json', 'w') as file:
    json.dump(df['scene'][520], file, default=str, indent=4)

# %%
ini_scene = df['scene'][5]
start_pose = []
for key in ini_scene['Robots']:
    if ini_scene['Robots'][key] is not None:
        start_pose.append(ini_scene['Robots'][key]['initial_pose'].tolist())

print(len(start_pose))
# Out:
# 3

# %%
df['trajectory'][520]['objs'][0]['steps']
# Out:
# array([{'pos': array([-0.54004653, -0.82543559,  0.68      ]), 'quat': array([0.77579737, 0.        , 0.        , 0.63098212])},
#        {'pos': array([-0.54004653, -0.82543559,  0.68      ]), 'quat': array([0.77579737, 0.        , 0.        , 0.63098212])},
#        {'pos': array([-0.54004653, -0.82543559,  0.68      ]), 'quat': array([0.77579737, 0.        , 0.        , 0.63098212])},
#        {'pos': array([-0.54004653, -0.82543559,  0.68      ]), 'quat': array([0.77579737, 0.        , 0.        , 0.63098212])},
#        {'pos': array([-0.54004653, -0.82543559,  0.68      ]), 'quat': array([0.77579737, 0.        , 0.        , 0.63098212])},
#        {'pos': array([-0.54004653, -0.82543559,  0.68      ]), 'quat': array([0.77579737, 0.        , 0.        , 0.63098212])},
#        {'pos': array([-0.54004653, -0.82543559,  0.68      ]), 'quat': array([0.77579737, 0.        , 0.        , 0.63098212])},
# ...
