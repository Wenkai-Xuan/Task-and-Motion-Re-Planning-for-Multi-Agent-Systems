# %%
import pandas as pd
import json
import numpy as np
import os

# %%
df = pd.read_parquet('samples_000030000_to_000032924.parquet')

# %%
df['scene'][5]
# Out:
# {'Objects': {'obj1': {'goal': {'abs_pos': array([ 0.74566464, -0.6309312 ,  0.545     ]),
#     'abs_quat': array([ 0.94136284, -0.        , -0.        , -0.33739591]),
#     'parent': 'table',
#     'pos': array([ 0.74566464, -0.6809312 ,  0.145     ]),
#     'quat': array([ 0.94136284, -0.        , -0.        , -0.33739591])},
#    'size': array([0.19, 0.23, 0.19, 0.01]),
#    'start': {'abs_pos': array([-0.72512275, -0.58829561,  0.545     ]),
#     'abs_quat': array([ 0.47373524, -0.        , -0.        , -0.88066731]),
#     'parent': 'table',
#     'pos': array([-0.72512275, -0.63829561,  0.145     ]),
#     'quat': array([ 0.47373524, -0.        , -0.        , -0.88066731])}},
#   'obj2': {'goal': {'abs_pos': array([-0.38056775, -0.27934932,  0.56      ]),
#     'abs_quat': array([0.10066103, 0.        , 0.        , 0.99492078]),
#     'parent': 'table',
#     'pos': array([-0.38056775, -0.32934932,  0.16      ]),
#     'quat': array([0.10066103, 0.        , 0.        , 0.99492078])},
#    'size': array([0.3 , 0.11, 0.22, 0.01]),
#    'start': {'abs_pos': array([ 0.09749255, -0.31601153,  0.56      ]),
#     'abs_quat': array([ 0.56349039, -0.        , -0.        , -0.82612262]),
#     'parent': 'table',
#     'pos': array([ 0.09749255, -0.36601153,  0.16      ]),
#     'quat': array([ 0.56349039, -0.        , -0.        , -0.82612262])}},
#   'obj3': None,
#   'obj4': None},
#  'Obstacles': {'World': {'pose': {'abs_pos': array([0., 0., 0.]),
#     'abs_quat': array([1., 0., 0., 0.]),
#     'pos': array([0., 0., 0.]),
#     'quat': array([1., 0., 0., 0.])}},
#   'base_link': {'pose': {'abs_pos': array([ 0.  , -1.1 ,  0.15]),
#     'abs_quat': array([0.70710678, 0.        , 0.        , 0.70710678]),
#     'pos': array([0., 0., 0.]),
#     'quat': array([1., 0., 0., 0.])}},
#   'base_link>dual_arm_bulkhead_joint': {'pose': {'abs_pos': array([ 0.   , -1.1  ,  0.374]),
#     'abs_quat': array([0.70710678, 0.        , 0.        , 0.70710678]),
#     'parent': 'base_link',
#     'pos': array([0.   , 0.   , 0.224]),
#     'quat': array([1., 0., 0., 0.])}},
#   'base_link>front_left_wheel': {'pose': {'abs_pos': array([-0.2854 , -0.844  ,  0.18282]),
#     'abs_quat': array([0., 0., 0., 1.]),
#     'parent': 'base_link',
#     'pos': array([0.256  , 0.2854 , 0.03282]),
#     'quat': array([0.70710678, 0.        , 0.        , 0.70710678])}},
#   'base_link>front_right_wheel': {'pose': {'abs_pos': array([ 0.2854 , -0.844  ,  0.18282]),
#     'abs_quat': array([0., 0., 0., 1.]),
#     'parent': 'base_link',
#     'pos': array([ 0.256  , -0.2854 ,  0.03282]),
#     'quat': array([0.70710678, 0.        , 0.        , 0.70710678])}},
#   'base_link>rear_left_wheel': {'pose': {'abs_pos': array([-0.2854 , -1.356  ,  0.18282]),
#     'abs_quat': array([0., 0., 0., 1.]),
#     'parent': 'base_link',
#     'pos': array([-0.256  ,  0.2854 ,  0.03282]),
#     'quat': array([0.70710678, 0.        , 0.        , 0.70710678])}},
#   'base_link>rear_right_wheel': {'pose': {'abs_pos': array([ 0.2854 , -1.356  ,  0.18282]),
#     'abs_quat': array([0., 0., 0., 1.]),
#     'parent': 'base_link',
#     'pos': array([-0.256  , -0.2854 ,  0.03282]),
#     'quat': array([0.70710678, 0.        , 0.        , 0.70710678])}},
#   'base_link_0': {'contact': -2,
#    'pose': {'abs_pos': array([ 0.  , -1.1 ,  0.25]),
#     'abs_quat': array([-0.70710678,  0.        ,  0.        ,  0.70710678]),
#     'parent': 'base_link',
#     'pos': array([0. , 0. , 0.1]),
#     'quat': array([0., 0., 0., 1.])},
#    'shape': 'box',
#    'size': array([1.     , 0.5709 , 0.22375, 0.     ])},
#   'base_link_1': {'contact': 0,
#    'mesh': "mesh:'/home/vTamp/rai-robotModels/husky/meshes/base_link_1.ply'",
#    'pose': {'abs_pos': array([ 0.  , -1.1 ,  0.15]),
#     'abs_quat': array([0.70710678, 0.        , 0.        , 0.70710678]),
#     'parent': 'base_link',
#     'pos': array([0., 0., 0.]),
#     'quat': array([1., 0., 0., 0.])},
#    'shape': 'mesh',
#    'size': array([], dtype=object)},
#   'dual_arm_bulkhead_joint': {'pose': {'abs_pos': array([ 0.   , -1.1  ,  0.374]),
#     'abs_quat': array([0.70710678, 0.        , 0.        , 0.70710678]),
#     'parent': 'base_link>dual_arm_bulkhead_joint',
#     'pos': array([0., 0., 0.]),
#     'quat': array([1., 0., 0., 0.])}},
#   'dual_arm_bulkhead_link': {'pose': {'abs_pos': array([ 0.   , -1.1  ,  0.374]),
#     'abs_quat': array([0.70710678, 0.        , 0.        , 0.70710678]),
#     'parent': 'dual_arm_bulkhead_joint',
#     'pos': array([0., 0., 0.]),
#     'quat': array([1., 0., 0., 0.])}},
#   'dual_arm_bulkhead_link>left_arm_bulkhead_joint': {'pose': {'abs_pos': array([-0.14891, -0.9775 ,  0.50771]),
#     'abs_quat': array([ 0.92387946,  0.        , -0.38268361,  0.        ]),
#     'parent': 'dual_arm_bulkhead_link',
#     'pos': array([0.1225 , 0.14891, 0.13371]),
#     'quat': array([ 0.65328143, -0.27059818, -0.27059818, -0.65328143])}},
#   'dual_arm_bulkhead_link>right_arm_bulkhead_joint': {'pose': {'abs_pos': array([ 0.14891, -0.9775 ,  0.50771]),
#     'abs_quat': array([0.92387946, 0.        , 0.38268361, 0.        ]),
#     'parent': 'dual_arm_bulkhead_link',
#     'pos': array([ 0.1225 , -0.14891,  0.13371]),
#     'quat': array([ 0.65328143,  0.27059818,  0.27059818, -0.65328143])}},
#   'dual_arm_bulkhead_link_1': {'contact': 0,
#    'mesh': "mesh:'/home/vTamp/rai-robotModels/husky/meshes/dual_arm_bulkhead_link_1.ply'",
#    'pose': {'abs_pos': array([ 0.   , -1.1  ,  0.374]),
#     'abs_quat': array([0.70710678, 0.        , 0.        , 0.70710678]),
#     'parent': 'base_link',
#     'pos': array([0.   , 0.   , 0.224]),
#     'quat': array([1., 0., 0., 0.])},
#    'shape': 'mesh',
#    'size': array([], dtype=object)},
#   'front_bumper_extension_link_1': {'contact': 0,
#    'mesh': "mesh:'/home/vTamp/rai-robotModels/husky/meshes/front_bumper_extension_link_1.ply'",
#    'pose': {'abs_pos': array([-1.07913678e-16, -6.14000000e-01,  2.41000000e-01]),
#     'abs_quat': array([0.70710678, 0.        , 0.        , 0.70710678]),
#     'parent': 'base_link',
#     'pos': array([0.486, 0.   , 0.091]),
#     'quat': array([1., 0., 0., 0.])},
#    'shape': 'mesh',
#    'size': array([], dtype=object)},
#   'front_bumper_link_1': {'contact': 0,
#    'mesh': "mesh:'/home/vTamp/rai-robotModels/husky/meshes/front_bumper_link_1.ply'",
#    'pose': {'abs_pos': array([-1.07913678e-16, -6.14000000e-01,  2.41000000e-01]),
#     'abs_quat': array([0.70710678, 0.        , 0.        , 0.70710678]),
#     'parent': 'base_link',
#     'pos': array([0.486, 0.   , 0.091]),
#     'quat': array([1., 0., 0., 0.])},
#    'shape': 'mesh',
#    'size': array([], dtype=object)},
#   'front_left_wheel': {'pose': {'abs_pos': array([-0.2854 , -0.844  ,  0.18282]),
#     'abs_quat': array([0., 0., 0., 1.]),
#     'parent': 'base_link>front_left_wheel',
#     'pos': array([0., 0., 0.]),
#     'quat': array([1., 0., 0., 0.])}},
#   'front_left_wheel_link': {'pose': {'abs_pos': array([-0.2854 , -0.844  ,  0.18282]),
#     'abs_quat': array([ 0.70710678, -0.        ,  0.        , -0.70710678]),
#     'parent': 'front_left_wheel',
#     'pos': array([-0., -0., -0.]),
#     'quat': array([-0.70710678,  0.        ,  0.        , -0.70710678])}},
#   'front_left_wheel_link_0': {'contact': -2,
#    'pose': {'abs_pos': array([-0.2854 , -0.844  ,  0.18282]),
#     'abs_quat': array([-0.70710678,  0.        ,  0.70710678,  0.        ]),
#     'parent': 'front_left_wheel',
#     'pos': array([-0., -0., -0.]),
#     'quat': array([0.        , 0.70710678, 0.        , 0.70710678])},
#    'shape': 'cylinder',
#    'size': array([0.    , 0.    , 0.1143, 0.1651])},
#   'front_left_wheel_link_1': {'contact': 0,
#    'mesh': "mesh:'/home/vTamp/rai-robotModels/husky/meshes/front_left_wheel_link_1.ply'",
#    'pose': {'abs_pos': array([-0.2854 , -0.844  ,  0.18282]),
#     'abs_quat': array([-0.70710678,  0.        , -0.        , -0.70710678]),
#     'parent': 'front_left_wheel',
#     'pos': array([-0., -0., -0.]),
#     'quat': array([-0.70710678,  0.        ,  0.        ,  0.70710678])},
#    'shape': 'mesh',
#    'size': array([], dtype=object)},
#   'front_right_wheel': {'pose': {'abs_pos': array([ 0.2854 , -0.844  ,  0.18282]),
#     'abs_quat': array([0., 0., 0., 1.]),
#     'parent': 'base_link>front_right_wheel',
#     'pos': array([0., 0., 0.]),
#     'quat': array([1., 0., 0., 0.])}},
#   'front_right_wheel_link': {'pose': {'abs_pos': array([ 0.2854 , -0.844  ,  0.18282]),
#     'abs_quat': array([-0.70710678,  0.        , -0.        , -0.70710678]),
#     'parent': 'front_right_wheel',
#     'pos': array([-0., -0., -0.]),
#     'quat': array([-0.70710678,  0.        ,  0.        ,  0.70710678])}},
#   'front_right_wheel_link_0': {'contact': -2,
#    'pose': {'abs_pos': array([ 0.2854 , -0.844  ,  0.18282]),
#     'abs_quat': array([-0.70710678,  0.        ,  0.70710678,  0.        ]),
#     'parent': 'front_right_wheel',
#     'pos': array([-0., -0., -0.]),
#     'quat': array([0.        , 0.70710678, 0.        , 0.70710678])},
#    'shape': 'cylinder',
#    'size': array([0.    , 0.    , 0.1143, 0.1651])},
#   'front_right_wheel_link_1': {'contact': 0,
#    'mesh': "mesh:'/home/vTamp/rai-robotModels/husky/meshes/front_right_wheel_link_1.ply'",
#    'pose': {'abs_pos': array([ 0.2854 , -0.844  ,  0.18282]),
#     'abs_quat': array([-0.70710678,  0.        , -0.        , -0.70710678]),
#     'parent': 'front_right_wheel',
#     'pos': array([-0., -0., -0.]),
#     'quat': array([-0.70710678,  0.        ,  0.        ,  0.70710678])},
#    'shape': 'mesh',
#    'size': array([], dtype=object)},
#   'inertial_link': {'pose': {'abs_pos': array([ 0.  , -1.1 ,  0.15]),
#     'abs_quat': array([0.70710678, 0.        , 0.        , 0.70710678]),
#     'parent': 'base_link',
#     'pos': array([0., 0., 0.]),
#     'quat': array([1., 0., 0., 0.])}},
#   'left_arm_bulkhead_joint': {'pose': {'abs_pos': array([-0.14891, -0.9775 ,  0.50771]),
#     'abs_quat': array([ 0.92387946,  0.        , -0.38268361,  0.        ]),
#     'parent': 'dual_arm_bulkhead_link>left_arm_bulkhead_joint',
#     'pos': array([0., 0., 0.]),
#     'quat': array([1., 0., 0., 0.])}},
#   'left_arm_bulkhead_link': {'pose': {'abs_pos': array([-0.14891, -0.9775 ,  0.50771]),
#     'abs_quat': array([ 0.92387946,  0.        , -0.38268361,  0.        ]),
#     'parent': 'left_arm_bulkhead_joint',
#     'pos': array([0., 0., 0.]),
#     'quat': array([1., 0., 0., 0.])}},
#   'rear_bumper_link_1': {'contact': 0,
#    'mesh': "mesh:'/home/vTamp/rai-robotModels/husky/meshes/rear_bumper_link_1.ply'",
#    'pose': {'abs_pos': array([ 1.0658141e-16, -1.5800000e+00,  2.4100000e-01]),
#     'abs_quat': array([-0.70710584,  0.        ,  0.        ,  0.70710772]),
#     'parent': 'base_link',
#     'pos': array([-0.48 ,  0.   ,  0.091]),
#     'quat': array([1.32679e-06, 0.00000e+00, 0.00000e+00, 1.00000e+00])},
#    'shape': 'mesh',
#    'size': array([], dtype=object)},
#   'rear_left_wheel': {'pose': {'abs_pos': array([-0.2854 , -1.356  ,  0.18282]),
#     'abs_quat': array([0., 0., 0., 1.]),
#     'parent': 'base_link>rear_left_wheel',
#     'pos': array([0., 0., 0.]),
#     'quat': array([1., 0., 0., 0.])}},
#   'rear_left_wheel_link': {'pose': {'abs_pos': array([-0.2854 , -1.356  ,  0.18282]),
#     'abs_quat': array([-0.70710678,  0.        , -0.        , -0.70710678]),
#     'parent': 'rear_left_wheel',
#     'pos': array([-0., -0., -0.]),
#     'quat': array([-0.70710678,  0.        ,  0.        ,  0.70710678])}},
#   'rear_left_wheel_link_0': {'contact': -2,
#    'pose': {'abs_pos': array([-0.2854 , -1.356  ,  0.18282]),
#     'abs_quat': array([-0.70710678,  0.        ,  0.70710678,  0.        ]),
#     'parent': 'rear_left_wheel',
#     'pos': array([-0., -0., -0.]),
#     'quat': array([0.        , 0.70710678, 0.        , 0.70710678])},
#    'shape': 'cylinder',
#    'size': array([0.    , 0.    , 0.1143, 0.1651])},
#   'rear_left_wheel_link_1': {'contact': 0,
#    'mesh': "mesh:'/home/vTamp/rai-robotModels/husky/meshes/rear_left_wheel_link_1.ply'",
#    'pose': {'abs_pos': array([-0.2854 , -1.356  ,  0.18282]),
#     'abs_quat': array([-0.70710678,  0.        , -0.        , -0.70710678]),
#     'parent': 'rear_left_wheel',
#     'pos': array([-0., -0., -0.]),
#     'quat': array([-0.70710678,  0.        ,  0.        ,  0.70710678])},
#    'shape': 'mesh',
#    'size': array([], dtype=object)},
#   'rear_right_wheel': {'pose': {'abs_pos': array([ 0.2854 , -1.356  ,  0.18282]),
#     'abs_quat': array([0., 0., 0., 1.]),
#     'parent': 'base_link>rear_right_wheel',
#     'pos': array([0., 0., 0.]),
#     'quat': array([1., 0., 0., 0.])}},
#   'rear_right_wheel_link': {'pose': {'abs_pos': array([ 0.2854 , -1.356  ,  0.18282]),
#     'abs_quat': array([-0.70710678,  0.        , -0.        , -0.70710678]),
#     'parent': 'rear_right_wheel',
#     'pos': array([-0., -0., -0.]),
#     'quat': array([-0.70710678,  0.        ,  0.        ,  0.70710678])}},
#   'rear_right_wheel_link_0': {'contact': -2,
#    'pose': {'abs_pos': array([ 0.2854 , -1.356  ,  0.18282]),
#     'abs_quat': array([-0.70710678,  0.        ,  0.70710678,  0.        ]),
#     'parent': 'rear_right_wheel',
#     'pos': array([-0., -0., -0.]),
#     'quat': array([0.        , 0.70710678, 0.        , 0.70710678])},
#    'shape': 'cylinder',
#    'size': array([0.    , 0.    , 0.1143, 0.1651])},
#   'rear_right_wheel_link_1': {'contact': 0,
#    'mesh': "mesh:'/home/vTamp/rai-robotModels/husky/meshes/rear_right_wheel_link_1.ply'",
#    'pose': {'abs_pos': array([ 0.2854 , -1.356  ,  0.18282]),
#     'abs_quat': array([-0.70710678,  0.        , -0.        , -0.70710678]),
#     'parent': 'rear_right_wheel',
#     'pos': array([-0., -0., -0.]),
#     'quat': array([-0.70710678,  0.        ,  0.        ,  0.70710678])},
#    'shape': 'mesh',
#    'size': array([], dtype=object)},
#   'right_arm_bulkhead_joint': {'pose': {'abs_pos': array([ 0.14891, -0.9775 ,  0.50771]),
#     'abs_quat': array([0.92387946, 0.        , 0.38268361, 0.        ]),
#     'parent': 'dual_arm_bulkhead_link>right_arm_bulkhead_joint',
#     'pos': array([0., 0., 0.]),
#     'quat': array([1., 0., 0., 0.])}},
#   'right_arm_bulkhead_link': {'pose': {'abs_pos': array([ 0.14891, -0.9775 ,  0.50771]),
#     'abs_quat': array([0.92387946, 0.        , 0.38268361, 0.        ]),
#     'parent': 'right_arm_bulkhead_joint',
#     'pos': array([0., 0., 0.]),
#     'quat': array([1., 0., 0., 0.])}},
#   'table': {'contact': 1,
#    'pose': {'abs_pos': array([0.  , 0.05, 0.4 ]),
#     'abs_quat': array([1., 0., 0., 0.]),
#     'parent': 'table_base',
#     'pos': array([ 0.  ,  0.05, -0.05]),
#     'quat': array([1., 0., 0., 0.])},
#    'shape': 'box',
#    'size': array([2.3 , 1.44, 0.05, 0.02])},
#   'table_base': {'contact': 0,
#    'pose': {'abs_pos': array([0.  , 0.  , 0.45]),
#     'abs_quat': array([1., 0., 0., 0.]),
#     'parent': 'World',
#     'pos': array([0.  , 0.  , 0.45]),
#     'quat': array([1., 0., 0., 0.])},
#    'size': array([0.03])},
#   'top_chassis_link_1': {'contact': 0,
#    'mesh': "mesh:'/home/vTamp/rai-robotModels/husky/meshes/top_chassis_link_1.ply'",
#    'pose': {'abs_pos': array([ 0.  , -1.1 ,  0.15]),
#     'abs_quat': array([0.70710678, 0.        , 0.        , 0.70710678]),
#     'parent': 'base_link',
#     'pos': array([0., 0., 0.]),
#     'quat': array([1., 0., 0., 0.])},
#    'shape': 'mesh',
#    'size': array([], dtype=object)},
#   'top_coll_left': {'contact': -2,
#    'pose': {'abs_pos': array([ 0.15, -1.1 ,  0.5 ]),
#     'abs_quat': array([-0.65321481,  0.27075895, -0.27075895,  0.65321481]),
#     'parent': 'base_link',
#     'pos': array([ 0.  , -0.15,  0.35]),
#     'quat': array([ 0.        ,  0.        , -0.38291098,  0.92378524])},
#    'shape': 'box',
#    'size': array([0.8 , 0.2 , 0.05, 0.  ])},
#   'top_coll_middle': {'contact': -2,
#    'pose': {'abs_pos': array([ 0.  , -1.1 ,  0.55]),
#     'abs_quat': array([-0.70710678,  0.        ,  0.        ,  0.70710678]),
#     'parent': 'base_link',
#     'pos': array([0. , 0. , 0.4]),
#     'quat': array([0., 0., 0., 1.])},
#    'shape': 'box',
#    'size': array([0.8 , 0.2 , 0.05, 0.  ])},
#   'top_coll_right': {'contact': -2,
#    'pose': {'abs_pos': array([-0.15, -1.1 ,  0.5 ]),
#     'abs_quat': array([-0.65321481, -0.27075895,  0.27075895,  0.65321481]),
#     'parent': 'base_link',
#     'pos': array([0.  , 0.15, 0.35]),
#     'quat': array([0.        , 0.        , 0.38291098, 0.92378524])},
#    'shape': 'box',
#    'size': array([0.8 , 0.2 , 0.05, 0.  ])}},
#  'Robots': {'a0_': {'base_pose': {'pos': array([ 0., -0.,  0.]),
#     'quat': array([0.70710678, 0.        , 0.        , 0.70710678])},
#    'end_effector_type': 1,
#    'home_pose': array([ 0.  ,  0.5 , -1.2 ,  0.  ,  1.57,  1.57]),
#    'initial_pose': array([ 0.  ,  0.5 , -1.2 ,  0.  ,  1.57,  1.57]),
#    'parent': 'left_arm_bulkhead_joint',
#    'type': 0},
#   'a1_': {'base_pose': {'pos': array([0., 0., 0.]),
#     'quat': array([0.70710678, 0.        , 0.        , 0.70710678])},
#    'end_effector_type': 1,
#    'home_pose': array([ 0.  ,  0.5 , -1.2 ,  0.  ,  1.57,  1.57]),
#    'initial_pose': array([ 0.  ,  0.5 , -1.2 ,  0.  ,  1.57,  1.57]),
#    'parent': 'right_arm_bulkhead_joint',
#    'type': 0}}}

# %%
with open('scene_5.json', 'w') as file:
    json.dump(df['scene'][5], file, default=str, indent=4)

# %%
dir(df['scene'][5])
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
dir(df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_accum_func',
#  '_add_numeric_operations',
#  '_agg_by_level',
#  '_agg_examples_doc',
#  '_agg_summary_and_see_also_doc',
#  '_align_frame',
#  '_align_series',
#  '_append',
#  '_arith_method',
#  '_as_manager',
#  '_attrs',
#  '_box_col_values',
#  '_can_fast_transpose',
#  '_check_inplace_and_allows_duplicate_labels',
#  '_check_inplace_setting',
#  '_check_is_chained_assignment_possible',
#  '_check_label_or_level_ambiguity',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_clip_with_one_bound',
#  '_clip_with_scalar',
#  '_cmp_method',
#  '_combine_frame',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_axes_from_arguments',
#  '_construct_result',
#  '_constructor',
#  '_constructor_sliced',
#  '_convert',
#  '_count_level',
#  '_data',
#  '_dir_additions',
#  '_dir_deletions',
#  '_dispatch_frame_op',
#  '_drop_axis',
#  '_drop_labels_or_levels',
#  '_ensure_valid_index',
#  '_find_valid_index',
#  '_flags',
#  '_from_arrays',
#  '_from_mgr',
#  '_get_agg_axis',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cleaned_column_resolvers',
#  '_get_column_array',
#  '_get_index_resolvers',
#  '_get_item_cache',
#  '_get_label_or_level_values',
#  '_get_numeric_data',
#  '_get_value',
#  '_getitem_bool_array',
#  '_getitem_multilevel',
#  '_gotitem',
#  '_hidden_attrs',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_info_repr',
#  '_init_mgr',
#  '_inplace_method',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_copy',
#  '_is_homogeneous_type',
#  '_is_label_or_level_reference',
#  '_is_label_reference',
#  '_is_level_reference',
#  '_is_mixed_type',
#  '_is_view',
#  '_iset_item',
#  '_iset_item_mgr',
#  '_iset_not_inplace',
#  '_item_cache',
#  '_iter_column_arrays',
#  '_ixs',
#  '_join_compat',
#  '_logical_func',
#  '_logical_method',
#  '_maybe_cache_changed',
#  '_maybe_update_cacher',
#  '_metadata',
#  '_mgr',
#  '_min_count_stat_function',
#  '_needs_reindex_multi',
#  '_protect_consolidate',
#  '_reduce',
#  '_reduce_axis1',
#  '_reindex_axes',
#  '_reindex_columns',
#  '_reindex_index',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_rename',
#  '_replace_columnwise',
#  '_repr_data_resource_',
#  '_repr_fits_horizontal_',
#  '_repr_fits_vertical_',
#  '_repr_html_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_sanitize_column',
#  '_series',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_axis_nocheck',
#  '_set_is_copy',
#  '_set_item',
#  '_set_item_frame_value',
#  '_set_item_mgr',
#  '_set_value',
#  '_setitem_array',
#  '_setitem_frame',
#  '_setitem_slice',
#  '_slice',
#  '_stat_axis',
#  '_stat_axis_name',
#  '_stat_axis_number',
#  '_stat_function',
#  '_stat_function_ddof',
#  '_take_with_is_copy',
#  '_to_dict_of_blocks',
#  '_typ',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'append',
#  'apply',
#  'applymap',
#  'asfreq',
#  'asof',
#  'assign',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'axes',
#  'backfill',
#  'between_time',
#  'bfill',
#  'bool',
#  'boxplot',
#  'clip',
#  'columns',
#  'combine',
#  'combine_first',
#  'compare',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'eval',
#  'ewm',
#  'expanding',
#  'explode',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'flags',
#  'floordiv',
#  'from_dict',
#  'from_records',
#  'ge',
#  'get',
#  'groupby',
#  'gt',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'infer_objects',
#  'info',
#  'insert',
#  'interpolate',
#  'isin',
#  'isna',
#  'isnull',
#  'items',
#  'iteritems',
#  'iterrows',
#  'itertuples',
#  'join',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'loc',
#  'lookup',
#  'lt',
#  'mad',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'melt',
#  'memory_usage',
#  'merge',
#  'metadata',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'ndim',
#  'ne',
#  'nlargest',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'obj_file',
#  'obstacles_file',
#  'pad',
#  'pct_change',
#  'pipe',
#  'pivot',
#  'pivot_table',
#  'plan',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'quantile',
#  'query',
#  'radd',
#  'rank',
#  'rdiv',
#  'reindex',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'robot_file',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'scene',
#  'scene_file',
#  'select_dtypes',
#  'sem',
#  'sequence',
#  'set_axis',
#  'set_flags',
#  'set_index',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'slice_shift',
#  'sort_index',
#  'sort_values',
#  'squeeze',
#  'stack',
#  'std',
#  'style',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_feather',
#  'to_gbq',
#  'to_hdf',
#  'to_html',
#  'to_json',
#  'to_latex',
#  'to_markdown',
#  'to_numpy',
#  'to_parquet',
#  'to_period',
#  'to_pickle',
#  'to_records',
#  'to_sql',
#  'to_stata',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'to_xml',
#  'trajectory',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tz_convert',
#  'tz_localize',
#  'unstack',
#  'update',
#  'value_counts',
#  'values',
#  'var',
#  'where',
#  'xs']

# %%
initial_states = []
initial_states.append({'objects': df['obj_file'][5]['objects'].tolist(), 'robots': df['robot_file'][5]['robots'].tolist()})
with open(f'initial_{5}.json', 'w') as file:
    json.dump(initial_states, file, default=str, indent=4)
